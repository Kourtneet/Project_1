# %%
# Import Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy.stats import linregress
import requests
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="f0c669e04c2a4354ac9fa7c5b6377a1f",
                                                           client_secret="8104dff9fa5d448199382fb2490ae43f"))

# %%
# Taylor
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="f0c669e04c2a4354ac9fa7c5b6377a1f",
  client_secret="8104dff9fa5d448199382fb2490ae43f"))
Tay_tracks={}
Tay_track_uri=[]
Tay_track_name= []
Tay_track_pop=[]
Tay_artist_name=[]

Tay_uri='spotify:artist:06HL4z0CvFAxyc27GXpf02'
Tay_results = sp.artist_top_tracks(Tay_uri, country='jp')
for track in Tay_results['tracks']:
    print (track['name'], track['artists'][0]['name'])
    print (track['uri'])
    
    Tay_track_uri.append(track['uri'])
    Tay_track_name.append(track['name'])
    Tay_track_pop.append(track['popularity'])
    Tay_artist_name.append(track['artists'][0]['name'])   
# print(bey_track_uri, bey_track_name)
Taydata=sp.audio_features(tracks=Tay_track_uri)

# Slicing these indexes so that they are the same len as other audio features
Tay_track_name = Tay_track_name[0:10]
Tay_track_pop= Tay_track_pop[0:10]
Tay_artist_name = Tay_artist_name[0:10]


Tay_tracks_tempo=[]
Tay_tracks_uri=[]
Tay_tracks_energy=[]
Tay_tracks_loudness=[]
Tay_tracks_speechiness=[]
Tay_tracks_danceability=[]
Tay_tracks_valence=[]

for Tay in range(len(Taydata)):
    Tay_tracks_tempo.append(Taydata[Tay]['tempo'])
    Tay_tracks_uri.append(Taydata[Tay]['uri'])
    Tay_tracks_energy.append(Taydata[Tay]['energy'])
    Tay_tracks_loudness.append(Taydata[Tay]['loudness'])
    Tay_tracks_speechiness.append(Taydata[Tay]['speechiness'])
    Tay_tracks_danceability.append(Taydata[Tay]['danceability'])
    Tay_tracks_valence.append(Taydata[Tay]['valence'])

Taydata_df=pd.DataFrame({
    'artist': Tay_artist_name,
    'popularity': Tay_track_pop,
    'track':Tay_track_name,
    'tempo': Tay_tracks_tempo,
    'energy':Tay_tracks_energy,
    'loudness': Tay_tracks_loudness,
    'speechiness':Tay_tracks_speechiness,
    'danceability':Tay_tracks_danceability,
    'valence': Tay_tracks_valence,
    'uri':Tay_tracks_uri,
    })
Taydata_df
# Out:
# Cruel Summer Taylor Swift
# spotify:track:1BxfuPKGuaTgP7aM0Bbdwr
# Is It Over Now? (Taylor's Version) (From The Vault) Taylor Swift
# spotify:track:1Iq8oo9XkmmvCQiGOfORiz
# Anti-Hero Taylor Swift
# spotify:track:0V3wPSX9ygBnCm8psDIegu
# Now That We Don't Talk (Taylor's Version) (From The Vault) Taylor Swift
# spotify:track:5KD6AEm19QnMbfWpfoOHMl
# You’re Losing Me (From The Vault) Taylor Swift
# spotify:track:3CWq0pAKKTWb0K4yiglDc4
# Lover Taylor Swift
# spotify:track:1dGr1c8CrMLDpV6mPbImSI
# "Slut!" (Taylor's Version) (From The Vault) Taylor Swift
# spotify:track:71BqAINEnezjQfxE4VuJfq
# cardigan Taylor Swift
# spotify:track:4R2kfaDFhslZEMJqAFNpdd
# august Taylor Swift
# spotify:track:3hUxzQpSfdDqwM3ZTFQY0K
# Blank Space Taylor Swift
# spotify:track:1kHEuJRasudLhjvnbfc4yS
#          artist  popularity  \
# 0  Taylor Swift          99
# 1  Taylor Swift          94
# 2  Taylor Swift          92
# 3  Taylor Swift          91
# 4  Taylor Swift          93
# 5  Taylor Swift          92
# ...
