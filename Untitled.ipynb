# %%
pip install spotipy --upgrade
# Out:
# Requirement already satisfied: spotipy in c:\users\labuser\anaconda3\envs\dev\lib\site-packages (2.23.0)
# Requirement already satisfied: redis>=3.5.3 in c:\users\labuser\anaconda3\envs\dev\lib\site-packages (from spotipy) (5.0.1)
# Requirement already satisfied: requests>=2.25.0 in c:\users\labuser\anaconda3\envs\dev\lib\site-packages (from spotipy) (2.31.0)
# Requirement already satisfied: six>=1.15.0 in c:\users\labuser\anaconda3\envs\dev\lib\site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\labuser\anaconda3\envs\dev\lib\site-packages (from spotipy) (1.26.18)
# Requirement already satisfied: async-timeout>=4.0.2 in c:\users\labuser\anaconda3\envs\dev\lib\site-packages (from redis>=3.5.3->spotipy) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\labuser\anaconda3\envs\dev\lib\site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\labuser\anaconda3\envs\dev\lib\site-packages (from requests>=2.25.0->spotipy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\labuser\anaconda3\envs\dev\lib\site-packages (from requests>=2.25.0->spotipy) (2023.11.17)
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="f0c669e04c2a4354ac9fa7c5b6377a1f",
                                                           client_secret="8104dff9fa5d448199382fb2490ae43f"))

results = sp.search(q='weezer', limit=20)
for idx, track in enumerate(results['tracks']['items']):
    print(idx, track['name'])
# Out:
# 0 Buddy Holly
# 1 Island In The Sun
# 2 Say It Ain't So
# 3 Undone - The Sweater Song
# 4 Beverly Hills
# 5 I Just Threw Out The Love Of My Dreams
# 6 Africa
# 7 Hash Pipe
# 8 My Name Is Jonas
# 9 Pork And Beans
# 10 Think Fast (feat. Weezer)
# 11 Take on Me
# 12 El Scorcho
# 13 Pink Triangle
# 14 All My Favorite Songs (feat. AJR)
# 15 Only In Dreams
# 16 No Scrubs
# 17 We Wish You A Merry Christmas
# 18 Perfect Situation
# 19 The World Has Turned And Left Me Here

# %%
# Out:
# track    : CUFF IT
#
# track    : Crazy In Love (feat. Jay-Z)
#
# track    : Halo
#
# track    : MY HOUSE
#
# track    : BREAK MY SOUL
#
# track    : Single Ladies (Put a Ring on It)
#
# track    : ALIEN SUPERSTAR
#
# track    : Beautiful Liar
#
# track    : HEATED
#
# track    : Love On Top

# %%
Tay = 'spotify:artist:06HL4z0CvFAxyc27GXpf02'

spotify = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="f0c669e04c2a4354ac9fa7c5b6377a1f",
                                                           client_secret="8104dff9fa5d448199382fb2490ae43f"))
results = spotify.artist_top_tracks(Tay)

for track in results['tracks'][:10]:
    print('track    : ' + track['name'])
    print()
# Out:
# track    : Cruel Summer
#
# track    : Is It Over Now? (Taylor's Version) (From The Vault)
#
# track    : Anti-Hero
#
# track    : Now That We Don't Talk (Taylor's Version) (From The Vault)
#
# track    : You’re Losing Me (From The Vault)
#
# track    : Lover
#
# track    : "Slut!" (Taylor's Version) (From The Vault)
#
# track    : cardigan
#
# track    : august
#
# track    : Blank Space

# %%
# Import Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy.stats import linregress
import requests
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# Beyonce
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="f0c669e04c2a4354ac9fa7c5b6377a1f",
  client_secret="8104dff9fa5d448199382fb2490ae43f"))
bey_tracks={}
bey_track_uri=[]
bey_track_name= []
bey_track_pop=[]
bey_artist_name=[]

bey_uri='spotify:artist:6vWDO969PvNqNYHIOW5v0m'
bey_results = sp.artist_top_tracks(bey_uri, country='US')
for track in bey_results['tracks']:
    print (track['name'], track['artists'][0]['name'])
    print (track['uri'])
    
    bey_track_uri.append(track['uri'])
    bey_track_name.append(track['name'])
    bey_track_pop.append(track['popularity'])
    bey_artist_name.append(track['artists'][0]['name'])   

# print(bey_track_uri, bey_track_name)
beydata=sp.audio_features(tracks=bey_track_uri)

# Slicing these indexes so that they are the same len as other audio features
bey_track_name = bey_track_name[0:9]
bey_track_pop= bey_track_pop[0:9]
bey_artist_name = bey_artist_name[0:9]


bey_tracks_tempo=[]
bey_tracks_uri=[]
bey_tracks_energy=[]
bey_tracks_loudness=[]
bey_tracks_speechiness=[]
bey_tracks_danceability=[]
bey_tracks_valence=[]

for bey in range(len(beydata)-1):
    bey_tracks_tempo.append(beydata[bey]['tempo'])
    bey_tracks_uri.append(beydata[bey]['uri'])
    bey_tracks_energy.append(beydata[bey]['energy'])
    bey_tracks_loudness.append(beydata[bey]['loudness'])
    bey_tracks_speechiness.append(beydata[bey]['speechiness'])
    bey_tracks_danceability.append(beydata[bey]['danceability'])
    bey_tracks_valence.append(beydata[bey]['valence'])

beydata_df=pd.DataFrame({
    'uri':bey_tracks_uri,
    'artist': bey_artist_name, 
    'track':bey_track_name,
    'tempo': bey_tracks_tempo,
    'energy':bey_tracks_energy,
    'loudness': bey_tracks_loudness,
    'speechiness':bey_tracks_speechiness,
    'danceability':bey_tracks_danceability,
    'popularity': bey_track_pop,
    'valence': bey_tracks_valence
    })
beydata_df
# Out:
# CUFF IT Beyoncé
# spotify:track:1xzi1Jcr7mEi9K2RfzLOqS
# Crazy In Love (feat. Jay-Z) Beyoncé
# spotify:track:5IVuqXILoxVWvWEPm82Jxr
# Halo Beyoncé
# spotify:track:3ERa3mEeOnrh2Mc47qM6T1
# MY HOUSE Beyoncé
# spotify:track:7omJfT9s6V2IpQNBYyq5C8
# BREAK MY SOUL Beyoncé
# spotify:track:5pyoxDZ1PX0KxBxiRVxA4U
# Single Ladies (Put a Ring on It) Beyoncé
# spotify:track:2ZBNclC5wm4GtiWaeh0DMx
# ALIEN SUPERSTAR Beyoncé
# spotify:track:1Hohk6AufHZOrrhMXZppax
# Beautiful Liar Beyoncé
# spotify:track:2HWWNoWEEEECwZhAiLg7ib
# HEATED Beyoncé
# spotify:track:1w7cgGZR86yWz1pA2puVJD
# Love On Top Beyoncé
# spotify:track:1z6WtY7X4HQJvzxC4UgkSf
#                                     uri   artist  \
# 0  spotify:track:1xzi1Jcr7mEi9K2RfzLOqS  Beyoncé
# 1  spotify:track:5IVuqXILoxVWvWEPm82Jxr  Beyoncé
# 2  spotify:track:3ERa3mEeOnrh2Mc47qM6T1  Beyoncé
# 3  spotify:track:7omJfT9s6V2IpQNBYyq5C8  Beyoncé
# 4  spotify:track:5pyoxDZ1PX0KxBxiRVxA4U  Beyoncé
# 5  spotify:track:2ZBNclC5wm4GtiWaeh0DMx  Beyoncé
# 6  spotify:track:1Hohk6AufHZOrrhMXZppax  Beyoncé
# 7  spotify:track:2HWWNoWEEEECwZhAiLg7ib  Beyoncé
# 8  spotify:track:1w7cgGZR86yWz1pA2puVJD  Beyoncé
#
#                               track    tempo  energy  loudness  speechiness  \
# 0                           CUFF IT  115.042   0.689    -5.668       0.1410
# 1       Crazy In Love (feat. Jay-Z)   99.165   0.770    -6.596       0.2260
# 2                              Halo   79.983   0.720    -5.908       0.0628
# 3                          MY HOUSE  181.428   0.849    -6.438       0.3430
# 4                     BREAK MY SOUL  114.942   0.887    -5.039       0.0795
# 5  Single Ladies (Put a Ring on It)  193.437   0.584    -5.293       0.2960
# 6                   ALIEN SUPERSTAR  121.892   0.641    -6.398       0.0998
# 7                    Beautiful Liar   91.977   0.751    -3.740       0.0703
# 8                            HEATED  110.952   0.732    -5.724       0.1640
#
#    danceability  popularity  valence
# 0         0.780          85    0.642
# 1         0.646          80    0.681
# 2         0.508          68    0.472
# 3         0.494          83    0.512
# 4         0.693          77    0.864
# 5         0.426          68    0.272
# 6         0.545          78    0.464
# 7         0.764          74    0.418
# 8         0.785          77    0.496

# %%
pip install python3-discogs-client
# Out:
# Collecting python3-discogs-client
#   Downloading python3_discogs_client-2.7-py3-none-any.whl.metadata (927 bytes)
# Requirement already satisfied: requests in c:\users\labuser\anaconda3\envs\dev\lib\site-packages (from python3-discogs-client) (2.31.0)
# Collecting oauthlib (from python3-discogs-client)
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ---------------------------------------- 0.0/151.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/151.7 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/151.7 kB ? eta -:--:--
#      --------- --------------------------- 41.0/151.7 kB 326.8 kB/s eta 0:00:01
#      ---------------------- -------------- 92.2/151.7 kB 581.0 kB/s eta 0:00:01
#      ------------------------------------ 151.7/151.7 kB 822.4 kB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in c:\users\labuser\anaconda3\envs\dev\lib\site-packages (from python3-discogs-client) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\labuser\anaconda3\envs\dev\lib\site-packages (from python-dateutil->python3-discogs-client) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\labuser\anaconda3\envs\dev\lib\site-packages (from requests->python3-discogs-client) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\labuser\anaconda3\envs\dev\lib\site-packages (from requests->python3-discogs-client) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\labuser\anaconda3\envs\dev\lib\site-packages (from requests->python3-discogs-client) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\labuser\anaconda3\envs\dev\lib\site-packages (from requests->python3-discogs-client) (2023.11.17)
# Downloading python3_discogs_client-2.7-py3-none-any.whl (17 kB)
# Installing collected packages: oauthlib, python3-discogs-client
# Successfully installed oauthlib-3.2.2 python3-discogs-client-2.7
# Note: you may need to restart the kernel to use updated packages.

# %%
import discogs_client
d = discogs_client.Client('ExampleApplication/0.1')

# %%
GET https://api.discogs.com/oauth/request_token
# Out:
#   Cell In[7], line 1
#     GET https://api.discogs.com/oauth/request_token
#         ^
# SyntaxError: invalid syntax

# %%
results = d.search('Stockholm By Night', type='release')
results.pages
1
artist = results[0].artists[0]
artist.name
u'Persuader, The'
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 results = d.search('Stockholm By Night', type='release')
# ----> 2 results.pages
#       3 1
#       4 artist = results[0].artists[0]
#
# File ~\anaconda3\envs\dev\lib\site-packages\discogs_client\models.py:336, in BasePaginatedResponse.pages(self)
#     333 @property
#     334 def pages(self):
#     335     if self._num_pages is None:
# --> 336         self._load_pagination_info()
#     337     return self._num_pages
#
# File ~\anaconda3\envs\dev\lib\site-packages\discogs_client\models.py:297, in BasePaginatedResponse._load_pagination_info(self)
#     296 def _load_pagination_info(self):
# --> 297     data = self.client._get(self._url_for_page(1))
#     298     self._pages[1] = [
#     299         self._transform(item) for item in data[self._list_key]
#     300     ]
#     301     self._num_pages = data['pagination']['pages']
#
# File ~\anaconda3\envs\dev\lib\site-packages\discogs_client\client.py:114, in Client._get(self, url)
#     113 def _get(self, url):
# --> 114     return self._request('GET', url)
#
# File ~\anaconda3\envs\dev\lib\site-packages\discogs_client\client.py:111, in Client._request(self, method, url, data)
#     109     return body
#     110 else:
# --> 111     raise HTTPError(body['message'], status_code)
#
# HTTPError: 401: You must authenticate to access this resource.
