# %%
# Import Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy.stats import linregress
import requests
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="f0c669e04c2a4354ac9fa7c5b6377a1f",
                                                           client_secret="8104dff9fa5d448199382fb2490ae43f"))

# %%
Bey = 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'

spotify = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="f0c669e04c2a4354ac9fa7c5b6377a1f",
                                                           client_secret="8104dff9fa5d448199382fb2490ae43f"))
results = spotify.artist_top_tracks(Bey)

for track in results['tracks'][:10]:
    print('track    : ' + track['name'])
    print()
# Out:
# track    : CUFF IT
#
# track    : Crazy In Love (feat. Jay-Z)
#
# track    : MY HOUSE
#
# track    : Halo
#
# track    : BREAK MY SOUL
#
# track    : Single Ladies (Put a Ring on It)
#
# track    : ALIEN SUPERSTAR
#
# track    : HEATED
#
# track    : Beautiful Liar
#
# track    : Love On Top

# %%
Tay = 'spotify:artist:06HL4z0CvFAxyc27GXpf02'

spotify = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="f0c669e04c2a4354ac9fa7c5b6377a1f",
                                                           client_secret="8104dff9fa5d448199382fb2490ae43f"))
results = spotify.artist_top_tracks(Tay)

for track in results['tracks'][:10]:
    print('track    : ' + track['name'])
    print()
# Out:
# track    : Cruel Summer
#
# track    : Is It Over Now? (Taylor's Version) (From The Vault)
#
# track    : Anti-Hero
#
# track    : Now That We Don't Talk (Taylor's Version) (From The Vault)
#
# track    : You’re Losing Me (From The Vault)
#
# track    : Lover
#
# track    : "Slut!" (Taylor's Version) (From The Vault)
#
# track    : cardigan
#
# track    : august
#
# track    : Blank Space

# %%
# Beyonce
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="f0c669e04c2a4354ac9fa7c5b6377a1f",
  client_secret="8104dff9fa5d448199382fb2490ae43f"))
bey_tracks={}
bey_track_uri=[]
bey_track_name= []
bey_track_pop=[]
bey_artist_name=[]

bey_uri='spotify:artist:6vWDO969PvNqNYHIOW5v0m'
bey_results = sp.artist_top_tracks(bey_uri, country='US')
for track in bey_results['tracks']:
    print (track['name'], track['artists'][0]['name'])
    print (track['uri'])
    
    bey_track_uri.append(track['uri'])
    bey_track_name.append(track['name'])
    bey_track_pop.append(track['popularity'])
    bey_artist_name.append(track['artists'][0]['name'])   

# print(bey_track_uri, bey_track_name)
beydata=sp.audio_features(tracks=bey_track_uri)

# Slicing these indexes so that they are the same len as other audio features
bey_track_name = bey_track_name[0:10]
bey_track_pop= bey_track_pop[0:10]
bey_artist_name = bey_artist_name[0:10]


bey_tracks_tempo=[]
bey_tracks_uri=[]
bey_tracks_energy=[]
bey_tracks_loudness=[]
bey_tracks_speechiness=[]
bey_tracks_danceability=[]
bey_tracks_valence=[]

for bey in range(len(beydata)):
    bey_tracks_tempo.append(beydata[bey]['tempo'])
    bey_tracks_uri.append(beydata[bey]['uri'])
    bey_tracks_energy.append(beydata[bey]['energy'])
    bey_tracks_loudness.append(beydata[bey]['loudness'])
    bey_tracks_speechiness.append(beydata[bey]['speechiness'])
    bey_tracks_danceability.append(beydata[bey]['danceability'])
    bey_tracks_valence.append(beydata[bey]['valence'])

beydata_df=pd.DataFrame({
    'artist': bey_artist_name,
    'popularity': bey_track_pop,
    'track':bey_track_name,
    'tempo': bey_tracks_tempo,
    'energy':bey_tracks_energy,
    'loudness': bey_tracks_loudness,
    'speechiness':bey_tracks_speechiness,
    'danceability':bey_tracks_danceability,
    'valence': bey_tracks_valence,
    'uri':bey_tracks_uri,
    })
beydata_df
# Out:
# CUFF IT Beyoncé
# spotify:track:1xzi1Jcr7mEi9K2RfzLOqS
# Crazy In Love (feat. Jay-Z) Beyoncé
# spotify:track:5IVuqXILoxVWvWEPm82Jxr
# MY HOUSE Beyoncé
# spotify:track:7omJfT9s6V2IpQNBYyq5C8
# Halo Beyoncé
# spotify:track:3ERa3mEeOnrh2Mc47qM6T1
# BREAK MY SOUL Beyoncé
# spotify:track:5pyoxDZ1PX0KxBxiRVxA4U
# Single Ladies (Put a Ring on It) Beyoncé
# spotify:track:2ZBNclC5wm4GtiWaeh0DMx
# ALIEN SUPERSTAR Beyoncé
# spotify:track:1Hohk6AufHZOrrhMXZppax
# HEATED Beyoncé
# spotify:track:1w7cgGZR86yWz1pA2puVJD
# Beautiful Liar Beyoncé
# spotify:track:2HWWNoWEEEECwZhAiLg7ib
# Love On Top Beyoncé
# spotify:track:1z6WtY7X4HQJvzxC4UgkSf
#     artist  popularity                             track    tempo  energy  \
# 0  Beyoncé          85                           CUFF IT  115.042   0.689
# 1  Beyoncé          80       Crazy In Love (feat. Jay-Z)   99.165   0.770
# 2  Beyoncé          84                          MY HOUSE  181.428   0.849
# ...

# %%
# Taylor
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="f0c669e04c2a4354ac9fa7c5b6377a1f",
  client_secret="8104dff9fa5d448199382fb2490ae43f"))
Tay_tracks={}
Tay_track_uri=[]
Tay_track_name= []
Tay_track_pop=[]
Tay_artist_name=[]

Tay_uri='spotify:artist:06HL4z0CvFAxyc27GXpf02'
Tay_results = sp.artist_top_tracks(Tay_uri, country='US')
for track in Tay_results['tracks']:
    print (track['name'], track['artists'][0]['name'])
    print (track['uri'])
    
    Tay_track_uri.append(track['uri'])
    Tay_track_name.append(track['name'])
    Tay_track_pop.append(track['popularity'])
    Tay_artist_name.append(track['artists'][0]['name'])   
# print(bey_track_uri, bey_track_name)
Taydata=sp.audio_features(tracks=Tay_track_uri)

# Slicing these indexes so that they are the same len as other audio features
Tay_track_name = Tay_track_name[0:10]
Tay_track_pop= Tay_track_pop[0:10]
Tay_artist_name = Tay_artist_name[0:10]


Tay_tracks_tempo=[]
Tay_tracks_uri=[]
Tay_tracks_energy=[]
Tay_tracks_loudness=[]
Tay_tracks_speechiness=[]
Tay_tracks_danceability=[]
Tay_tracks_valence=[]

for Tay in range(len(Taydata)):
    Tay_tracks_tempo.append(Taydata[Tay]['tempo'])
    Tay_tracks_uri.append(Taydata[Tay]['uri'])
    Tay_tracks_energy.append(Taydata[Tay]['energy'])
    Tay_tracks_loudness.append(Taydata[Tay]['loudness'])
    Tay_tracks_speechiness.append(Taydata[Tay]['speechiness'])
    Tay_tracks_danceability.append(Taydata[Tay]['danceability'])
    Tay_tracks_valence.append(Taydata[Tay]['valence'])

Taydata_df=pd.DataFrame({
    'artist': Tay_artist_name,
    'popularity': Tay_track_pop,
    'track':Tay_track_name,
    'tempo': Tay_tracks_tempo,
    'energy':Tay_tracks_energy,
    'loudness': Tay_tracks_loudness,
    'speechiness':Tay_tracks_speechiness,
    'danceability':Tay_tracks_danceability,
    'valence': Tay_tracks_valence,
    'uri':Tay_tracks_uri,
    })
Taydata_df
# Out:
# Cruel Summer Taylor Swift
# spotify:track:1BxfuPKGuaTgP7aM0Bbdwr
# Is It Over Now? (Taylor's Version) (From The Vault) Taylor Swift
# spotify:track:1Iq8oo9XkmmvCQiGOfORiz
# Anti-Hero Taylor Swift
# spotify:track:0V3wPSX9ygBnCm8psDIegu
# Now That We Don't Talk (Taylor's Version) (From The Vault) Taylor Swift
# spotify:track:5KD6AEm19QnMbfWpfoOHMl
# You’re Losing Me (From The Vault) Taylor Swift
# spotify:track:3CWq0pAKKTWb0K4yiglDc4
# Lover Taylor Swift
# spotify:track:1dGr1c8CrMLDpV6mPbImSI
# "Slut!" (Taylor's Version) (From The Vault) Taylor Swift
# spotify:track:71BqAINEnezjQfxE4VuJfq
# cardigan Taylor Swift
# spotify:track:4R2kfaDFhslZEMJqAFNpdd
# august Taylor Swift
# spotify:track:3hUxzQpSfdDqwM3ZTFQY0K
# Blank Space Taylor Swift
# spotify:track:1p80LdxRV74UKvL8gnD7ky
#          artist  popularity  \
# 0  Taylor Swift          99
# 1  Taylor Swift          94
# 2  Taylor Swift          92
# 3  Taylor Swift          91
# 4  Taylor Swift          93
# 5  Taylor Swift          92
# ...

# %%
# Mariah
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="f0c669e04c2a4354ac9fa7c5b6377a1f",
  client_secret="8104dff9fa5d448199382fb2490ae43f"))
Mariah_tracks={}
Mariah_track_uri=[]
Mariah_track_name= []
Mariah_track_pop=[]
Mariah_artist_name=[]

Mariah_uri='spotify:artist:4iHNK0tOyZPYnBU7nGAgpQ'
Mariah_results = sp.artist_top_tracks(Mariah_uri, country='US')
for track in Mariah_results['tracks']:
    print (track['name'], track['artists'][0]['name'])
    print (track['uri'])
    
    Mariah_track_uri.append(track['uri'])
    Mariah_track_name.append(track['name'])
    Mariah_track_pop.append(track['popularity'])
    Mariah_artist_name.append(track['artists'][0]['name'])   
# print(bey_track_uri, bey_track_name)
Mariahdata=sp.audio_features(tracks=Mariah_track_uri)

# Slicing these indexes so that they are the same len as other audio features
Mariah_track_name = Mariah_track_name[0:10]
Mariah_track_pop= Mariah_track_pop[0:10]
Mariah_artist_name = Mariah_artist_name[0:10]


Mariah_tracks_tempo=[]
Mariah_tracks_uri=[]
Mariah_tracks_energy=[]
Mariah_tracks_loudness=[]
Mariah_tracks_speechiness=[]
Mariah_tracks_danceability=[]
Mariah_tracks_valence=[]

for Mariah in range(len(Mariahdata)):
    Mariah_tracks_tempo.append(Mariahdata[Mariah]['tempo'])
    Mariah_tracks_uri.append(Mariahdata[Mariah]['uri'])
    Mariah_tracks_energy.append(Mariahdata[Mariah]['energy'])
    Mariah_tracks_loudness.append(Mariahdata[Mariah]['loudness'])
    Mariah_tracks_speechiness.append(Mariahdata[Mariah]['speechiness'])
    Mariah_tracks_danceability.append(Mariahdata[Mariah]['danceability'])
    Mariah_tracks_valence.append(Mariahdata[Mariah]['valence'])

Mariahdata_df=pd.DataFrame({
    'artist': Mariah_artist_name,
    'popularity': Mariah_track_pop,
    'track': Mariah_track_name,
    'tempo': Mariah_tracks_tempo,
    'energy': Mariah_tracks_energy,
    'loudness': Mariah_tracks_loudness,
    'speechiness': Mariah_tracks_speechiness,
    'danceability': Mariah_tracks_danceability,
    'valence': Mariah_tracks_valence,
    'uri':Mariah_tracks_uri,
    })
Mariahdata_df
# Out:
# All I Want for Christmas Is You Mariah Carey
# spotify:track:0bYg9bo50gSsH3LtXe2SQn
# Christmas (Baby Please Come Home) Mariah Carey
# spotify:track:3PIDciSFdrQxSQSihim3hN
# O Holy Night Mariah Carey
# spotify:track:3B7FO3kJ5kv3mX7yiaB7sT
# Oh Santa! (feat. Ariana Grande & Jennifer Hudson) Mariah Carey
# spotify:track:2VkuxjlbnbaBiWYpdBGVol
# We Belong Together Mariah Carey
# spotify:track:3LmvfNUQtglbTrydsdIqFU
# Obsessed Mariah Carey
# spotify:track:3IcIIZMMS7UArJJPtEHXG8
# Fantasy Mariah Carey
# spotify:track:6xkryXuiZU360Lngd4sx13
# Santa Claus Is Comin' to Town Mariah Carey
# spotify:track:1f2lkuLldqRzvaFjJdjGXX
# I Know What You Want (feat. Flipmode Squad) Busta Rhymes
# spotify:track:0YImOCkIJ2PWhCXaURCZnY
# Touch My Body Mariah Carey
# spotify:track:2aEuXA1KswHlCGPOuPmCOW
#          artist  popularity  \
# 0  Mariah Carey          99
# 1  Mariah Carey          87
# 2  Mariah Carey          81
# 3  Mariah Carey          69
# 4  Mariah Carey          73
# ...

# %%
one_file_song_data  = pd.concat(mariahdata_df, beydata_df, Taydata_df, on=['popularity','uri', 'artist', 'track', 'tempo', 'energy', 'loudness', 'speechiness', 'danceability', 'valence'], ignore_index=True)
one_file_song_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 one_file_song_data  = pd.concat(mariahdata_df, beydata_df, Taydata_df, on=['popularity','uri', 'artist', 'track', 'tempo', 'energy', 'loudness', 'speechiness', 'danceability', 'valence'], ignore_index=True)
#       2 one_file_song_data
#
# NameError: name 'mariahdata_df' is not defined

# %%
one_file_song_data_sorted = one_file_song_data.sort_values(by=['popularity'],ascending=False)
one_file_song_data_sorted
